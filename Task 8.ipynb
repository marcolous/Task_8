# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('smoke_detection_iot.csv')

# %%
df
# Out:
#          num         UTC  Temperature  Humidity  TVOC  eCO2  Raw_H2  \
# 0          0  1654733331       20.000     57.36     0   400   12306
# 1          1  1654733332       20.015     56.67     0   400   12345
# 2          2  1654733333       20.029     55.96     0   400   12374
# 3          3  1654733334       20.044     55.28     0   400   12390
# 4          4  1654733335       20.059     54.69     0   400   12403
# ...      ...         ...          ...       ...   ...   ...     ...
# 62625  62625  1655130047       18.438     15.79   625   400   13723
# 62626  62626  1655130048       18.653     15.87   612   400   13731
# 62627  62627  1655130049       18.867     15.84   627   400   13725
# 62628  62628  1655130050       19.083     16.04   638   400   13712
# 62629  62629  1655130051       19.299     16.52   643   400   13696
#
#        Raw_Ethanol  Pressure   PM1   PM2   NC0    NC1    NC2   CNT  Fire_Alarm
# ...

# %%
count = df['Fire_Alarm'].value_counts()

# %%
plt.pie(count, autopct='%1.1f%%', wedgeprops={'linewidth': 1, 'edgecolor': 'black'}, startangle= 180)
colors = plt.cm.get_cmap('tab20').colors[:len(count)]
labels = ['Yes_Fire', 'No_Fire']
plt.legend(labels, loc='center', bbox_to_anchor=(1.5,0.7))
plt.show()
# Out:
# C:\Users\GIGbyte\AppData\Local\Temp\ipykernel_325776\3059114338.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20').colors[:len(count)]
